# %%
import os
import nltk
import ssl
import streamlit as st
import random
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
ssl._create_default_https_context = ssl._create_unverified_context
nltk.data.path.append(os.path.abspath("nltk_data"))
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jishmohan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
intents=[
    {
        "tag": "Science Fiction",
        "patterns": ["Tell me about sci-fi movies", "What are some science fiction movies?", "Suggest a sci-fi movie", "Sci-fi movies","Sci-fi","Science Fiction","sci-fi"],
        "responses": [
            "Dune (2021)", 
            "The Martian (2015)", 
            "Interstellar (2014)", 
            "Blade Runner 2049 (2017)", 
            "Snowpiercer (2013)", 
            "The Matrix (1999)",
            "Minority Report (2002)", 
            "The Fifth Element (1997)", 
            "Elysium (2013)", 
            "The Terminator (1984)"
        ]
    },
    {
        "tag": "Fantasy",
        "patterns": ["Tell me about fantasy movies", "What are some fantasy movies?", "Suggest fantasy movies","fantasy","Fantasy","fantasy movies"],
        "responses": [
            "Harry Potter and the Sorcerer's Stone (2001)", 
            "The Lord of the Rings: The Fellowship of the Ring (2001)", 
            "The Chronicles of Narnia: The Lion, the Witch, and the Wardrobe (2005)", 
            "The Hobbit: An Unexpected Journey (2012)", 
            "The Princess Bride (1987)", 
            "Pan's Labyrinth (2006)",
            "Stardust (2007)", 
            "The Dark Crystal (1982)", 
            "Alice in Wonderland (2010)", 
            "The Wizard of Oz (1939)"
        ]
    },
    {
        "tag": "Mystery",
        "patterns": ["Tell me about mystery movies", "What are some mystery movies?","Mystery", "Suggest a mystery movie", "mystery","mystery movies","suspense"],
        "responses": [
            "Gone Girl (2014)", 
            "Sherlock Holmes (2009)", 
            "The Girl with the Dragon Tattoo (2011)", 
            "Knives Out (2019)", 
            "Prisoners (2013)", 
            "The Sixth Sense (1999)",
            "The Prestige (2006)", 
            "Murder on the Orient Express (2017)", 
            "Zodiac (2007)", 
            "The Usual Suspects (1995)"
        ]
    },
    {
        "tag": "Romance",
        "patterns": ["Tell me about romance movies","romance", "What are some romance movies?", "Suggest a romance movie", "love","Romance movies","Romance"],
        "responses": [
            "Pride and Prejudice (2005)", 
            "The Notebook (2004)", 
            "La La Land (2016)", 
            "Titanic (1997)", 
            "The Fault in Our Stars (2014)", 
            "Eternal Sunshine of the Spotless Mind (2004)",
            "500 Days of Summer (2009)", 
            "Notting Hill (1999)", 
            "Crazy, Stupid, Love (2011)", 
            "When Harry Met Sally (1989)"
        ]
    },
    {
        "tag": "Horror",
        "patterns": ["Tell me about horror movies", "What are some horror movies?","Horror", "scary movies","fear", "Suggest a horror movie"],
        "responses": [
            "It (2017)", 
            "The Shining (1980)", 
            "A Quiet Place (2018)", 
            "Get Out (2017)", 
            "Hereditary (2018)", 
            "The Conjuring (2013)",
            "The Exorcist (1973)", 
            "Psycho (1960)", 
            "Halloween (1978)", 
            "The Babadook (2014)"
        ]
    },
    {
        "tag": "Non-fiction",
        "patterns": ["Tell me about non-fiction movies", "What are some non-fiction movies?", "Suggest a non-fiction movie","Non-fiction movies","realistic"],
        "responses": [
            "Won't You Be My Neighbor? (2018)", 
            "Free Solo (2018)", 
            "13th (2016)", 
            "The Social Network (2010)", 
            "The Last Dance (2020)", 
            "Jiro Dreams of Sushi (2011)",
            "The Fog of War (2003)", 
            "Won't You Be My Neighbor? (2018)", 
            "The Inventor: Out for Blood in Silicon Valley (2019)", 
            "Inside Job (2010)"
        ]
    },
    {
        "tag": "Biography",
        "patterns": ["Tell me about biography movies", "What are some biographical movies?", "Suggest a biography movie","autobiography","biography movies"],
        "responses": [
            "The Theory of Everything (2014)", 
            "The Pursuit of Happyness (2006)", 
            "Bohemian Rhapsody (2018)", 
            "A Beautiful Mind (2001)", 
            "The Social Network (2010)", 
            "Selma (2014)",
            "The Iron Lady (2011)", 
            "Catch Me If You Can (2002)", 
            "Ray (2004)", 
            "The Founder (2016)"
        ]
    },
    {
        "tag": "Self-Help",
        "patterns": ["Tell me about self-help movies", "What are some self-help movies?", "Suggest a self-help movie","self-care"],
        "responses": [
            "The Pursuit of Happyness (2006)", 
            "Eat Pray Love (2010)", 
            "The Secret (2006)", 
            "Julie & Julia (2009)", 
            "The Shift (2009)", 
            "Yes Man (2008)",
            "The Bucket List (2007)", 
            "The Intern (2015)", 
            "The Alchemist (2016)", 
            "Under the Tuscan Sun (2003)"
        ]
    },
    {
        "tag": "Historical Fiction",
        "patterns": ["Tell me about historical fiction movies","history","What are some historical fiction movies?", "Suggest a historical fiction movie","historical"],
        "responses": [
            "Schindler's List (1993)", 
            "The Imitation Game (2014)", 
            "12 Years a Slave (2013)", 
            "The King's Speech (2010)", 
            "The Pianist (2002)", 
            "Dunkirk (2017)",
            "The Last Samurai (2003)", 
            "Gladiator (2000)", 
            "The Bridge on the River Kwai (1957)", 
            "Lincoln (2012)"
        ]
    },
    {
        "tag": "Thriller",
        "patterns": ["Tell me about thriller movies", "What are some thriller movies?", "Suggest a thriller movie","thrillers"],
        "responses": [
            "The Dark Knight (2008)", 
            "Gone Girl (2014)", 
            "Seven (1995)", 
            "Shutter Island (2010)", 
            "The Girl with the Dragon Tattoo (2011)", 
            "Inception (2010)",
            "Memento (2000)", 
            "The Prestige (2006)", 
            "Fight Club (1999)", 
            "The Silence of the Lambs (1991)"
        ]
    },
    {
        "tag": "Young Adult",
        "patterns": ["Tell me about young adult movies", "What are some young adult movies?", "Suggest a young adult movie"],
        "responses": [
            "The Hunger Games (2012)", 
            "The Fault in Our Stars (2014)", 
            "The Perks of Being a Wallflower (2012)", 
            "Divergent (2014)", 
            "To All the Boys I've Loved Before (2018)", 
            "The Maze Runner (2014)",
            "Paper Towns (2015)", 
            "Love, Simon (2018)", 
            "The Spectacular Now (2013)", 
            "Twilight (2008)"
        ]
    },
    {
        "tag": "Classic Literature",
        "patterns": ["Tell me about classic movies", "What are some classic movies?", "Suggest a classic movie","literature"],
        "responses": [
            "Casablanca (1942)", 
            "Gone with the Wind (1939)", 
            "The Godfather (1972)", 
            "Citizen Kane (1941)", 
            "12 Angry Men (1957)", 
            "One Flew Over the Cuckoo's Nest (1975)",
            "Some Like It Hot (1959)", 
            "The Maltese Falcon (1941)", 
            "The Grapes of Wrath (1940)", 
            "The Sound of Music (1965)"
        ]
    },
    {
        "tag": "Comedy",
        "patterns": [
            "Tell me about comedy movies", 
            "What are some comedy movies?", 
            "Suggest a comedy movie", 
            "Comedy movies", 
            "Funny movies", 
            "Movies for a laugh"
        ],
        "responses": [
            "The Hangover (2009)", 
            "Superbad (2007)", 
            "Anchorman: The Legend of Ron Burgundy (2004)", 
            "Monty Python and the Holy Grail (1975)", 
            "Dumb and Dumber (1994)", 
            "The Grand Budapest Hotel (2014)",
            "Step Brothers (2008)", 
            "Tropic Thunder (2008)", 
            "Ferris Bueller's Day Off (1986)", 
            "21 Jump Street (2012)"
        ]
    },
    {
        "tag": "Tragedy",
        "patterns": [
            "Tell me about tragedy movies", 
            "What are some tragedy movies?", 
            "Suggest a tragedy movie", 
            "Tragic movies", 
            "Movies with tragic endings", 
            "Heartbreaking movies"
         ],
        "responses": [
            "The Green Mile (1999)", 
            "Schindler's List (1993)", 
            "Requiem for a Dream (2000)", 
            "The Fault in Our Stars (2014)", 
            "The Pursuit of Happyness (2006)", 
            "Atonement (2007)",
            "The Boy in the Striped Pajamas (2008)", 
            "My Sister's Keeper (2009)", 
            "Beaches (1988)", 
            "Marley & Me (2008)"
        ]
    }
]

# %%
# Create the vectorizer and classifier

vectorizer = TfidfVectorizer()
clf = LogisticRegression(random_state=0, max_iter=10000)

# Preprocess the data
tags = []
patterns = []
for intent in intents:
    for pattern in intent['patterns']:
        tags.append(intent['tag'])
        patterns.append(pattern)

# Training the model
x = vectorizer.fit_transform(patterns)
y = tags
clf.fit(x, y)
# Out:
# LogisticRegression(max_iter=10000, random_state=0)

# %%
# Track the last response for each tag
last_responses = {}

def chatbot(input_text):
    global last_responses

    # Transform the user input and predict the tag
    input_text = vectorizer.transform([input_text])
    tag = clf.predict(input_text)[0]

    # Find the intent corresponding to the tag
    for intent in intents:
        if intent['tag'] == tag:
            responses = intent['responses']

            # If the tag has been responded to before, remove the last response from the options
            if tag in last_responses and last_responses[tag] in responses:
                responses = [resp for resp in responses if resp != last_responses[tag]]

            # Choose a new response randomly
            response = random.choice(responses)

            # Update the last response for this tag
            last_responses[tag] = response
            return response

# %%
def main():
    st.title("Movie Recommendation Chatbot")
    st.write("Welcome to the movie recommendation chatbot! Ask me about movies in different genres, and I'll suggest some great films!")

    counter = 0
    counter += 1
    user_input = st.text_input("You:", key=f"user_input_{counter}")

    if user_input:
        # Check for "bye" or "goodbye" before invoking the chatbot function
        if user_input.lower() in ['bye', 'goodbye', 'thank you', 'thanks']:
            st.write("Thank you for chatting with me. Have a great day!")
            st.stop()

        # Get response from the chatbot function
        response = chatbot(user_input)
        st.text_area("Chatbot:", value=response, height=100, max_chars=None, key=f"chatbot_response_{counter}")

if __name__ == "__main__":
    main()
# Out:
# 2024-12-11 12:09:45.048
# ...
#   command:
#
#     streamlit run C:\Users\Jishmohan\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
